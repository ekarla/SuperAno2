# %%
from apiclient.discovery import build
from apiclient.errors import HttpError
import pandas as pd

# %%
ytkey = "AIzaSyBst8skcQCiGzp2fq-2-A5uoZ0W_Dav2iA"
youtube = build('youtube','v3',developerKey=ytkey)

# %%
playListID = "PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N"
playListName = "CRUD COM PYTHON"
nextPage_token = None

# %%
playlist_videos = []
res = youtube.playlistItems().list(part = 'snippet',playlistId = playListID,maxResults = 10 ).execute()
res
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'ODGez-uEox4rBvPdv0HqKdKo1iw',
#  'nextPageToken': 'EAAaBlBUOkNBbw',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'MZDUiclbKNGyWpytkyv8fNW99fA',
#    'id': 'UExibkFzSjZ6bGlkdnN6U1hueHBsZllndEI2S1EtZlotTi4yMDhBMkNBNjRDMjQxQTg1',
#    'snippet': {'publishedAt': '2021-06-20T22:20:17Z',
#     'channelId': 'UCL-mk7btv-dHI5hY2Tl1GHg',
#     'title': 'CRUD com Python - #1 Introdução',
#     'description': 'Hoje iniciamos o curso de CRUD (create, read, update, delete) com a linguagem de programação Python. Aprenderemos do zero a fazer as operações com o banco de dados.\nTutorial Completo: https://webdesignemfoco.com/cursos/python/crud-com-python-1-introducao\n\nToday we started the CRUD (create, read, update, delete) course with the Python programming language. We will learn from scratch how to do transactions with the database.\nFull Tutorial: https://webdesignemfoco.com/cursos/python/crud-com-python-1-introducao\n\nPlaylist: https://www.youtube.com/watch?v=-vrXnewHrwA&list=PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N\n\nSuporte Premium: webdesignemfoco@gmail.com\n\n#python #cursodepython #django',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-vrXnewHrwA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-vrXnewHrwA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-vrXnewHrwA/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/-vrXnewHrwA/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/-vrXnewHrwA/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Webdesign em Foco',
#     'playlistId': 'PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N',
#     'position': 0,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '-vrXnewHrwA'},
#     'videoOwnerChannelTitle': 'Webdesign em Foco',
#     'videoOwnerChannelId': 'UCL-mk7btv-dHI5hY2Tl1GHg'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'tqcJxEDkiaMW6NvpoH4NPGaOKpQ',
#    'id': 'UExibkFzSjZ6bGlkdnN6U1hueHBsZllndEI2S1EtZlotTi5ENDU4Q0M4RDExNzM1Mjcy',
#    'snippet': {'publishedAt': '2021-06-20T22:20:17Z',
#     'channelId': 'UCL-mk7btv-dHI5hY2Tl1GHg',
#     'title': 'CRUD com Python - #2 Template',
#     'description': "Nesse tutorial criaremos o template do nosso sistema de CRUD com Python\ndesenvolvendo os elementos de marcação HTML.\nTutorial Completo: https://webdesignemfoco.com/cursos/python/crud-com-python-2-template\n\nIn this tutorial we'll create the template of the our CRUD system with Python, developing the HTML elements. \nFull Tutorial: https://webdesignemfoco.com/cursos/python/crud-com-python-2-template\n\nPlaylist: https://www.youtube.com/watch?v=-vrXnewHrwA&list=PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N\n\nSuporte Premium: webdesignemfoco@gmail.com\n\n#python #crudpython #cursodepython",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HwDXUPZBRoc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HwDXUPZBRoc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HwDXUPZBRoc/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/HwDXUPZBRoc/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/HwDXUPZBRoc/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Webdesign em Foco',
#     'playlistId': 'PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N',
#     'position': 1,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'HwDXUPZBRoc'},
#     'videoOwnerChannelTitle': 'Webdesign em Foco',
#     'videoOwnerChannelId': 'UCL-mk7btv-dHI5hY2Tl1GHg'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'lH4la0J095oqiqErxca--3lFElI',
#    'id': 'UExibkFzSjZ6bGlkdnN6U1hueHBsZllndEI2S1EtZlotTi45RTgxNDRBMzUwRjQ0MDhC',
#    'snippet': {'publishedAt': '2021-06-20T22:20:17Z',
#     'channelId': 'UCL-mk7btv-dHI5hY2Tl1GHg',
#     'title': 'CRUD com Python - #3 Formulário e Banco de Dados',
#     'description': "Nesse tutorial trabalharemos com banco de dados Sqlite e com o formulário\ninterligado as colunas do banco.\nTutorial Completo: https://webdesignemfoco.com/cursos/python/crud-com-python-3-banco-de-dados-e-formulario\n\nIn this tutorial we'll work with Sqlite database and forms integrated with database columns.\nFull Tutorial: https://webdesignemfoco.com/cursos/python/crud-com-python-3-banco-de-dados-e-formulario\n\nPlaylist: https://www.youtube.com/watch?v=-vrXnewHrwA&list=PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N\n\nSuporte Premium: webdesignemfoco@gmail.com\n\n#python #pythonwithsqlite #crudpython",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/V4nCkSKajZU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/V4nCkSKajZU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/V4nCkSKajZU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/V4nCkSKajZU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/V4nCkSKajZU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Webdesign em Foco',
#     'playlistId': 'PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N',
#     'position': 2,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'V4nCkSKajZU'},
#     'videoOwnerChannelTitle': 'Webdesign em Foco',
#     'videoOwnerChannelId': 'UCL-mk7btv-dHI5hY2Tl1GHg'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'Xg0hr4kH74PfTNv4OVKFR4RdrA0',
#    'id': 'UExibkFzSjZ6bGlkdnN6U1hueHBsZllndEI2S1EtZlotTi4yMUQyQTQzMjRDNzMyQTMy',
#    'snippet': {'publishedAt': '2021-06-20T22:20:17Z',
#     'channelId': 'UCL-mk7btv-dHI5hY2Tl1GHg',
#     'title': 'CRUD com Python - #4 Create e Read',
#     'description': 'Nesse tutorial iniciaremos o CRUD no Python na prática, iniciando pelo create com adição de dados e o read com a leitura de dados do banco.\nTutorial Completo: https://webdesignemfoco.com/cursos/python/crud-com-python-4-create-e-read\n\nIn this tutorial we will start CRUD in Python in practice, starting with create with the addition of data and read with the reading of database data.\nFull Tutorial: https://webdesignemfoco.com/cursos/python/crud-com-python-4-create-e-read\n\nPlaylist: https://www.youtube.com/watch?v=-vrXnewHrwA&list=PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N\n\nSuporte Premium: webdesignemfoco@gmail.com\nInstagram: @webdesignemfococom\nFacebook: webdesignemfoco\n\n#crudpython #python #cursodepython',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_Uk3JOmNZlA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_Uk3JOmNZlA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_Uk3JOmNZlA/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/_Uk3JOmNZlA/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/_Uk3JOmNZlA/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Webdesign em Foco',
#     'playlistId': 'PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N',
#     'position': 3,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '_Uk3JOmNZlA'},
#     'videoOwnerChannelTitle': 'Webdesign em Foco',
#     'videoOwnerChannelId': 'UCL-mk7btv-dHI5hY2Tl1GHg'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'wgbQ2WhpB1mXV9z2GxO_V3b79VI',
#    'id': 'UExibkFzSjZ6bGlkdnN6U1hueHBsZllndEI2S1EtZlotTi41QTY1Q0UxMTVCODczNThE',
#    'snippet': {'publishedAt': '2021-06-20T22:20:17Z',
#     'channelId': 'UCL-mk7btv-dHI5hY2Tl1GHg',
#     'title': 'CRUD com Python - #5 Update',
#     'description': 'Nesse tutorial trabalharemos com a parte de edição e update de dados no banco através de um sistema CRUD desenvolvido com Python.\nTutorial Completo: https://webdesignemfoco.com/cursos/python/crud-com-python-5-update\n\nIn this tutorial we will work with editing and updating data in the database using a CRUD system developed with Python.\nFull Tutorial: https://webdesignemfoco.com/cursos/python/crud-com-python-5-update\n\nPlaylist: https://www.youtube.com/watch?v=-vrXnewHrwA&list=PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N\n\nSuporte Premium: webdesignemfoco@gmail.com\nInstagram: @webdesignemfococom\nFacebook: webdesignemfoco\n\n#crud #python #cursodepython',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kmhGZNFeAb4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kmhGZNFeAb4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kmhGZNFeAb4/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/kmhGZNFeAb4/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/kmhGZNFeAb4/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Webdesign em Foco',
#     'playlistId': 'PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N',
#     'position': 4,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'kmhGZNFeAb4'},
#     'videoOwnerChannelTitle': 'Webdesign em Foco',
#     'videoOwnerChannelId': 'UCL-mk7btv-dHI5hY2Tl1GHg'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'jW-_NBkWjVhUgLjvMlQUXTGx0-0',
#    'id': 'UExibkFzSjZ6bGlkdnN6U1hueHBsZllndEI2S1EtZlotTi5EQUE1NTFDRjcwMDg0NEMz',
#    'snippet': {'publishedAt': '2021-06-20T22:20:17Z',
#     'channelId': 'UCL-mk7btv-dHI5hY2Tl1GHg',
#     'title': 'CRUD com Python - #6 Delete e Ajax',
#     'description': 'Nessa videoaula trabalharemos com o delete utilizando o ajax para fornecer\num maior dinamismo a nossa aplicação.\nTutorial Completo: https://webdesignemfoco.com/cursos/python/crud-com-python-6-delete-e-ajax\n\nIn this video lesson we will work with delete using ajax to provide more dynamism to our application.\nFull Tutorial: https://webdesignemfoco.com/cursos/python/crud-com-python-6-delete-e-ajax\n\nPlaylist: https://www.youtube.com/watch?v=-vrXnewHrwA&list=PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N\n\nSuporte Premium: webdesignemfoco@gmail.com\nInstagram: @webdesignemfococom\nFacebook: webdesignemfoco\n\n#crud #python #pythonajax',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jzmXruc_wFs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jzmXruc_wFs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jzmXruc_wFs/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/jzmXruc_wFs/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/jzmXruc_wFs/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Webdesign em Foco',
#     'playlistId': 'PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N',
#     'position': 5,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'jzmXruc_wFs'},
#     'videoOwnerChannelTitle': 'Webdesign em Foco',
#     'videoOwnerChannelId': 'UCL-mk7btv-dHI5hY2Tl1GHg'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'Qf6zgethmp5MSNJI-yG01QlU2Nc',
#    'id': 'UExibkFzSjZ6bGlkdnN6U1hueHBsZllndEI2S1EtZlotTi41Mzk2QTAxMTkzNDk4MDhF',
#    'snippet': {'publishedAt': '2021-06-20T22:20:17Z',
#     'channelId': 'UCL-mk7btv-dHI5hY2Tl1GHg',
#     'title': 'CRUD com Python - #7 Paginação e Busca',
#     'description': 'Nesse tutorial aprenderemos como realizar a paginação e a busca de dados\nno banco utilizando a linguagem de programação Python.\nTutorial Completo: https://webdesignemfoco.com/cursos/python/crud-com-python-7-paginacao-e-busca\n\nIn this tutorial we will learn how to perform pagination and search for data in the bank using the Python programming language.\nFull Tutorial: https://webdesignemfoco.com/cursos/python/crud-com-python-7-paginacao-e-busca\n\nPlaylist: https://www.youtube.com/watch?v=-vrXnewHrwA&list=PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N\n\nSuporte Premium: webdesignemfoco@gmail.com\nInstagram: @webdesignemfococom\nFacebook: webdesignemfoco\n\n#crud #python #tutorialpython',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PMjwCB5rShY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PMjwCB5rShY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PMjwCB5rShY/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/PMjwCB5rShY/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/PMjwCB5rShY/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Webdesign em Foco',
#     'playlistId': 'PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N',
#     'position': 6,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'PMjwCB5rShY'},
#     'videoOwnerChannelTitle': 'Webdesign em Foco',
#     'videoOwnerChannelId': 'UCL-mk7btv-dHI5hY2Tl1GHg'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'VEwVoHTyjgCsr5Vi3z23pUU9MXw',
#    'id': 'UExibkFzSjZ6bGlkdnN6U1hueHBsZllndEI2S1EtZlotTi4zMDg5MkQ5MEVDMEM1NTg2',
#    'snippet': {'publishedAt': '2021-06-20T22:20:17Z',
#     'channelId': 'UCL-mk7btv-dHI5hY2Tl1GHg',
#     'title': 'CRUD com Python - #8 Usando o MySQL',
#     'description': 'Nesta aula faremos o mesmo CRUD realizado anteriormente com SQLITE, agora com o banco de dados MySQL.\nTutorial Completo: https://webdesignemfoco.com/cursos/python/crud-com-python-8-usando-o-mysql\n\nIn this class we will do the same CRUD performed previously with SQLITE, now with the MySQL database.\nFull Tutorial: https://webdesignemfoco.com/cursos/python/crud-com-python-8-usando-o-mysql\n\nPlaylist: https://www.youtube.com/watch?v=-vrXnewHrwA&list=PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N\n\nSuporte Premium: webdesignemfoco@gmail.com\nInstagram: @webdesignemfococom\nFacebook: webdesignemfoco\n\n#crudpython #pythonmysql #cursodepython',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QAlylVkwst0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QAlylVkwst0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QAlylVkwst0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/QAlylVkwst0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/QAlylVkwst0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Webdesign em Foco',
#     'playlistId': 'PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N',
#     'position': 7,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'QAlylVkwst0'},
#     'videoOwnerChannelTitle': 'Webdesign em Foco',
#     'videoOwnerChannelId': 'UCL-mk7btv-dHI5hY2Tl1GHg'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'lq0XJmOFEEjEja4Zhpu1H3pJGl4',
#    'id': 'UExibkFzSjZ6bGlkdnN6U1hueHBsZllndEI2S1EtZlotTi45ODRDNTg0QjA4NkFBNkQy',
#    'snippet': {'publishedAt': '2021-06-20T22:20:17Z',
#     'channelId': 'UCL-mk7btv-dHI5hY2Tl1GHg',
#     'title': 'CRUD com Python - #9 Deploy',
#     'description': "Na aula de hoje iremos fazer o deploy da nossa aplicação utilizando o Python com Django e o banco de dados SQLite.\nTutorial Completo: https://webdesignemfoco.com/cursos/python/crud-com-python-9-deploy\n\nIn today's class we will deploy our application using Python with Django and the SQLite database.\nFull Tutorial: https://webdesignemfoco.com/cursos/python/crud-com-python-9-deploy\n\nPlaylist: https://www.youtube.com/watch?v=-vrXnewHrwA&list=PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N\n\nSuporte Premium: webdesignemfoco@gmail.com\nInstagram: @webdesignemfococom\nFacebook: webdesignemfoco\n\n#crud #python #crudpython",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZhPxdaX5OJ8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZhPxdaX5OJ8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZhPxdaX5OJ8/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/ZhPxdaX5OJ8/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/ZhPxdaX5OJ8/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Webdesign em Foco',
#     'playlistId': 'PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N',
#     'position': 8,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'ZhPxdaX5OJ8'},
#     'videoOwnerChannelTitle': 'Webdesign em Foco',
#     'videoOwnerChannelId': 'UCL-mk7btv-dHI5hY2Tl1GHg'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'MIB0yVcNkv1ESaMOR53-iGznEnU',
#    'id': 'UExibkFzSjZ6bGlkdnN6U1hueHBsZllndEI2S1EtZlotTi5EMEEwRUY5M0RDRTU3NDJC',
#    'snippet': {'publishedAt': '2021-06-20T22:20:17Z',
#     'channelId': 'UCL-mk7btv-dHI5hY2Tl1GHg',
#     'title': 'CRUD com Python - #10 Deploy com MySQL',
#     'description': "Na aula de hoje iremos fazer o deploy da nossa aplicação utilizando o Python com Django e o banco de dados MySQL.\nTutorial Completo: https://webdesignemfoco.com/cursos/python/crud-com-python-10-deploy-com-mysql\n\nIn today's class we will deploy our application using Python with Django and the MySQL database.\nFull Tutorial: https://webdesignemfoco.com/cursos/python/crud-com-python-10-deploy-com-mysql\n\nPlaylist: https://www.youtube.com/playlist?list=PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N\n\nSuporte Premium: webdesignemfoco@gmail.com\nInstagram: @webdesignemfococom\nFacebook: webdesignemfoco\n\n#crudpython #pythonmysql #python",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Evg48WN4arw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Evg48WN4arw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Evg48WN4arw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Evg48WN4arw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Evg48WN4arw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Webdesign em Foco',
#     'playlistId': 'PLbnAsJ6zlidvszSXnxplfYgtB6KQ-fZ-N',
#     'position': 9,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'Evg48WN4arw'},
#     'videoOwnerChannelTitle': 'Webdesign em Foco',
#     'videoOwnerChannelId': 'UCL-mk7btv-dHI5hY2Tl1GHg'}}],
#  'pageInfo': {'totalResults': 11, 'resultsPerPage': 10}}

# %%
playlist_videos = res['items']
playlist_videos[0]['snippet']['resourceId']['videoId']
# Out:
# '-vrXnewHrwA'

# %%
id_videos = list(map(lambda x:x['snippet']['resourceId']['videoId'],playlist_videos))

# %%
description_videos = list(map(lambda x:x['snippet']['description'],playlist_videos))
#description_videos

# %%
estatisc_videos = []

for videos_id in id_videos:
    res = youtube.videos().list(part = 'statistics',id = videos_id).execute()
    estatisc_videos += res['items']

# %%
title_video = list(map(lambda x:x['snippet']['title'],playlist_videos))
title_video
# Out:
# ['CRUD com Python - #1 Introdução',
#  'CRUD com Python - #2 Template',
#  'CRUD com Python - #3 Formulário e Banco de Dados',
#  'CRUD com Python - #4 Create e Read',
#  'CRUD com Python - #5 Update',
#  'CRUD com Python - #6 Delete e Ajax',
#  'CRUD com Python - #7 Paginação e Busca',
#  'CRUD com Python - #8 Usando o MySQL',
#  'CRUD com Python - #9 Deploy',
#  'CRUD com Python - #10 Deploy com MySQL']

# %%
likes = list(map(lambda x:int(x['statistics']['likeCount']),estatisc_videos))
likes
# Out:
# [787, 456, 437, 284, 218, 178, 174, 140, 104, 87]

# %%
playlist_df = pd.DataFrame({'Titulo':title_video,'Likes':likes,'Id_video':id_videos,'Descrição':description_videos})
playlist_df
# Out:
#                                              Titulo  Likes     Id_video  \
# 0                   CRUD com Python - #1 Introdução    787  -vrXnewHrwA
# 1                     CRUD com Python - #2 Template    456  HwDXUPZBRoc
# 2  CRUD com Python - #3 Formulário e Banco de Dados    437  V4nCkSKajZU
# 3                CRUD com Python - #4 Create e Read    284  _Uk3JOmNZlA
# 4                       CRUD com Python - #5 Update    218  kmhGZNFeAb4
# 5                CRUD com Python - #6 Delete e Ajax    178  jzmXruc_wFs
# 6            CRUD com Python - #7 Paginação e Busca    174  PMjwCB5rShY
# 7               CRUD com Python - #8 Usando o MySQL    140  QAlylVkwst0
# 8                       CRUD com Python - #9 Deploy    104  ZhPxdaX5OJ8
# 9            CRUD com Python - #10 Deploy com MySQL     87  Evg48WN4arw
#
#                                            Descrição
# 0  Hoje iniciamos o curso de CRUD (create, read, ...
# 1  Nesse tutorial criaremos o template do nosso s...
# 2  Nesse tutorial trabalharemos com banco de dado...
# 3  Nesse tutorial iniciaremos o CRUD no Python na...
# 4  Nesse tutorial trabalharemos com a parte de ed...
# 5  Nessa videoaula trabalharemos com o delete uti...
# 6  Nesse tutorial aprenderemos como realizar a pa...
# 7  Nesta aula faremos o mesmo CRUD realizado ante...
# 8  Na aula de hoje iremos fazer o deploy da nossa...
# 9  Na aula de hoje iremos fazer o deploy da nossa...

# %%
comentarios = youtube.commentThreads().list(part = 'snippet',videoId ="-vrXnewHrwA" ).execute()
comentarios['items'][2]['snippet']['topLevelComment']['snippet']['textDisplay']
# Out:
# 'Obrigado por ajudar! Desejo todo sucesso para sua vida'

# %%
comentarios_videos = []

for videos_id in id_videos:
    res = youtube.commentThreads().list(part = 'snippet',videoId =videos_id ).execute()
    comentario = comentarios['items'][0]['snippet']['topLevelComment']['snippet']['textDisplay']
    print(comentario)
# Out:
# Professor, boa noite. No caso, uso Linux. Tem algumas coisas que ainda não entendo, e gostaria da sua ajuda. Criei a pasta python e acessei. Quando dou python -m venv venv retorna /usr/bin/python: No module named venv<br>Peguei alguns tutoriais sobre esse retorno, mas, sem sucesso.
# Professor, boa noite. No caso, uso Linux. Tem algumas coisas que ainda não entendo, e gostaria da sua ajuda. Criei a pasta python e acessei. Quando dou python -m venv venv retorna /usr/bin/python: No module named venv<br>Peguei alguns tutoriais sobre esse retorno, mas, sem sucesso.
# Professor, boa noite. No caso, uso Linux. Tem algumas coisas que ainda não entendo, e gostaria da sua ajuda. Criei a pasta python e acessei. Quando dou python -m venv venv retorna /usr/bin/python: No module named venv<br>Peguei alguns tutoriais sobre esse retorno, mas, sem sucesso.
# Professor, boa noite. No caso, uso Linux. Tem algumas coisas que ainda não entendo, e gostaria da sua ajuda. Criei a pasta python e acessei. Quando dou python -m venv venv retorna /usr/bin/python: No module named venv<br>Peguei alguns tutoriais sobre esse retorno, mas, sem sucesso.
# Professor, boa noite. No caso, uso Linux. Tem algumas coisas que ainda não entendo, e gostaria da sua ajuda. Criei a pasta python e acessei. Quando dou python -m venv venv retorna /usr/bin/python: No module named venv<br>Peguei alguns tutoriais sobre esse retorno, mas, sem sucesso.
# Professor, boa noite. No caso, uso Linux. Tem algumas coisas que ainda não entendo, e gostaria da sua ajuda. Criei a pasta python e acessei. Quando dou python -m venv venv retorna /usr/bin/python: No module named venv<br>Peguei alguns tutoriais sobre esse retorno, mas, sem sucesso.
# Professor, boa noite. No caso, uso Linux. Tem algumas coisas que ainda não entendo, e gostaria da sua ajuda. Criei a pasta python e acessei. Quando dou python -m venv venv retorna /usr/bin/python: No module named venv<br>Peguei alguns tutoriais sobre esse retorno, mas, sem sucesso.
# Professor, boa noite. No caso, uso Linux. Tem algumas coisas que ainda não entendo, e gostaria da sua ajuda. Criei a pasta python e acessei. Quando dou python -m venv venv retorna /usr/bin/python: No module named venv<br>Peguei alguns tutoriais sobre esse retorno, mas, sem sucesso.
# Professor, boa noite. No caso, uso Linux. Tem algumas coisas que ainda não entendo, e gostaria da sua ajuda. Criei a pasta python e acessei. Quando dou python -m venv venv retorna /usr/bin/python: No module named venv<br>Peguei alguns tutoriais sobre esse retorno, mas, sem sucesso.
# Professor, boa noite. No caso, uso Linux. Tem algumas coisas que ainda não entendo, e gostaria da sua ajuda. Criei a pasta python e acessei. Quando dou python -m venv venv retorna /usr/bin/python: No module named venv<br>Peguei alguns tutoriais sobre esse retorno, mas, sem sucesso.

# %%
search_response = youtube.search().list(q='matematica',part="id,snippet").execute()

# %%
search_response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'pSxF_v5GqaY6SYYY-d8QIONRJxI',
#  'nextPageToken': 'CAUQAA',
#  'regionCode': 'BR',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'UjHfXL2Cv2057_KEJGnZxhMEPs0',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UCW9_n8p_Byz-4k8wV1tnUBg'},
#    'snippet': {'publishedAt': '2014-03-20T00:04:32Z',
#     'channelId': 'UCW9_n8p_Byz-4k8wV1tnUBg',
#     'title': 'Ferretto Matemática',
#     'description': 'O canal de matemática do Professor Ferretto sintetiza o que milhares de estudantes desejam: é a OPORTUNIDADE única para adquirir um elevado ...',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/P-x6kRp61pfRiEnrz9RsLCcz2rYLVBC6t_wZC3BEbyJxk7XxZ3EYrQNdNYkyjb3HCFEZL0V_=s88-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/P-x6kRp61pfRiEnrz9RsLCcz2rYLVBC6t_wZC3BEbyJxk7XxZ3EYrQNdNYkyjb3HCFEZL0V_=s240-c-k-c0xffffffff-no-rj-mo'},
#      'high': {'url': 'https://yt3.ggpht.com/P-x6kRp61pfRiEnrz9RsLCcz2rYLVBC6t_wZC3BEbyJxk7XxZ3EYrQNdNYkyjb3HCFEZL0V_=s800-c-k-c0xffffffff-no-rj-mo'}},
#     'channelTitle': 'Ferretto Matemática',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2014-03-20T00:04:32Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LtJxCZSj_wvJu-LQESPkgz5MLck',
#    'id': {'kind': 'youtube#video', 'videoId': 'ddZHkCUcYRM'},
#    'snippet': {'publishedAt': '2020-06-02T14:46:34Z',
#     'channelId': 'UC3KTSc6Ihj3vKI6aaYYpN_A',
#     'title': 'TUDO DE MATEMÁTICA BÁSICA - Aulão Completo (MESTRES DO ENEM)',
#     'description': 'Quer aprender TUDO DE EXATAS Rápido e a Tempo do ENEM 2021? Conheça os MESTRES DO ENEM, meu curso completo e INTENSIVO de Matemática, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ddZHkCUcYRM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ddZHkCUcYRM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ddZHkCUcYRM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Umberto Mannarino',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-06-02T14:46:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'qTu0n6g9CbOA9d0HFN-NatfcPQM',
#    'id': {'kind': 'youtube#playlist',
#     'playlistId': 'PLTPg64KdGgYgFpOFt2TETLdEuBB4fvxxf'},
#    'snippet': {'publishedAt': '2014-03-20T23:09:15Z',
#     'channelId': 'UCW9_n8p_Byz-4k8wV1tnUBg',
#     'title': 'Matemática Básica (Curso Completo)',
#     'description': 'O curso de Matemática Básica oferece a melhor oportunidade para adquirir um conhecimento sólido das operações, propriedades e métodos matemáticos.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/az6OYFS7AUA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/az6OYFS7AUA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/az6OYFS7AUA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Ferretto Matemática',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2014-03-20T23:09:15Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'KMldQuFkdI6mw81tUZneY5EERR0',
#    'id': {'kind': 'youtube#video', 'videoId': 'g7aHAxkOKmk'},
#    'snippet': {'publishedAt': '2021-09-30T10:22:54Z',
#     'channelId': 'UCnAxhqL43T3XjagjZpYoQAA',
#     'title': '30/09/21 - 5º ano EF - Matemática - As frações equivalentes - Aula 08',
#     'description': 'Docente estúdio: André Luiz Ramos de Santana Santos.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/g7aHAxkOKmk/default_live.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/g7aHAxkOKmk/mqdefault_live.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/g7aHAxkOKmk/hqdefault_live.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '5o ano EF - CMSP',
#     'liveBroadcastContent': 'live',
#     'publishTime': '2021-09-30T10:22:54Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'i8dP2vOSc-0mo8pqSJB5k8XTx9Y',
#    'id': {'kind': 'youtube#playlist',
#     'playlistId': 'PLTPg64KdGgYhYpS5nXdFgdqEZDOS5lARB'},
#    'snippet': {'publishedAt': '2018-05-29T13:26:46Z',
#     'channelId': 'UCW9_n8p_Byz-4k8wV1tnUBg',
#     'title': 'Matemática Básica - 2021 (Curso Completo)',
#     'description': 'Olá pessoal, beleza?! Essa é a mais recente playlist de Matemática Básica aqui do Canal. Os vídeos estão todos atualizados, com novidades e tudo o que você ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/e78_5WIssSU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/e78_5WIssSU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/e78_5WIssSU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Ferretto Matemática',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-05-29T13:26:46Z'}}]}
